# %%
import csv
import pandas as pd
from datetime import datetime
import calendar
import warnings
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
warnings.filterwarnings("ignore")

# %%
try:
    df = pd.read_csv('../CSV/mdc.csv', encoding='utf-8')
except UnicodeDecodeError:
    try:
        df = pd.read_csv('../CSV/mdc.csv', encoding='latin1')
    except UnicodeDecodeError:
        try:
            df = pd.read_csv('../CSV/mdc.csv', encoding='ISO-8859-1')
        except UnicodeDecodeError:
            df = pd.read_csv('../CSV/mdc.csv', encoding='utf-16')

# %%
df = df[['title','entity','year','mpa_rating','imdb_rating','tomato_meter','imdb_gross']]
df.head()
# Out:
#              title  entity  year mpa_rating  imdb_rating  tomato_meter  \
# 0  Captain America  MARVEL  1944   Approved          5.5             0
# 1  Howard the Duck  MARVEL  1986         PG          4.7            13
# 2            Blade  MARVEL  1998          R          7.1            55
# 3            X-Men  MARVEL  2000      PG-13          7.4            82
# 4         Blade II  MARVEL  2002          R          6.7            57
#
#    imdb_gross
# 0           0
# 1    16300000
# 2    70090000
# 3   157300000
# 4    82350000

# %%
def format_as_dollars(imdb_gross):
    return '${:,.2f}'.format(imdb_gross)
df['imdb_gross'] = df['imdb_gross'].apply(format_as_dollars)

# %%
marvel_df = df[df['entity'] == 'MARVEL']
marvel_df = marvel_df.reset_index(drop=True)
dc_df = df[df['entity'] == 'DC']
dc_df = dc_df.reset_index(drop=True)
dc_df
# Out:
#                                  title entity  year mpa_rating  imdb_rating  \
# 0            Superman and the Mole-Men     DC  1951     Passed          5.7
# 1                    Batman: The Movie     DC  1966         PG          6.5
# 2                             Superman     DC  1978         PG          7.3
# 3                          Superman II     DC  1980         PG          6.8
# 4                          Swamp Thing     DC  1982         PG          5.4
# 5                         Superman III     DC  1983         PG          5.0
# 6                            Supergirl     DC  1984         PG          4.4
# 7     Superman IV: The Quest for Peace     DC  1987         PG          3.7
# 8            The Return of Swamp Thing     DC  1989      PG-13          4.6
# 9                               Batman     DC  1989      PG-13          7.5
# 10                      Batman Returns     DC  1992      PG-13          7.0
# 11                      Batman Forever     DC  1995      PG-13          5.4
# 12                      Batman & Robin     DC  1997      PG-13          3.8
# 13                               Steel     DC  1997      PG-13          2.9
# 14                            Catwoman     DC  2004      PG-13          3.4
# 15                         Constantine     DC  2005          R          7.0
# 16                       Batman Begins     DC  2005      PG-13          8.2
# 17                    Superman Returns     DC  2006      PG-13          6.0
# 18                     The Dark Knight     DC  2008      PG-13          9.0
# 19                            Watchmen     DC  2009          R          7.6
# 20                           Jonah Hex     DC  2010      PG-13          4.7
# 21                       Green Lantern     DC  2011      PG-13          5.5
# 22               The Dark Knight Rises     DC  2012      PG-13          8.4
# 23                        Man of Steel     DC  2013      PG-13          7.0
# 24  Batman v Superman: Dawn of Justice     DC  2016      PG-13          6.4
# 25                       Suicide Squad     DC  2016      PG-13          5.9
# 26                        Wonder Woman     DC  2017      PG-13          7.4
# 27                      Justice League     DC  2017      PG-13          6.1
# 28                             Aquaman     DC  2018      PG-13          6.9
# 29                             Shazam!     DC  2019      PG-13          7.0
# 30                               Joker     DC  2019          R          8.4
# 31                       Birds of Prey     DC  2020          R          6.1
# 32                   Wonder Woman 1984     DC  2020      PG-13          5.4
#
#     tomato_meter       imdb_gross
# 0              0            $0.00
# 1             79            $0.00
# 2             94  $134,220,000.00
# 3             86  $108,190,000.00
# 4             63            $0.00
# 5             30   $59,950,000.00
# 6              9   $13,600,000.00
# 7             11   $15,680,000.00
# 8             44      $190,000.00
# 9             71  $251,190,000.00
# 10            80  $162,830,000.00
# 11            38  $184,030,000.00
# 12            12  $107,330,000.00
# 13            12    $1,710,000.00
# 14             9   $40,200,000.00
# 15            46   $75,980,000.00
# 16            84  $206,850,000.00
# 17            75  $200,080,000.00
# 18            94  $534,860,000.00
# 19            65  $107,510,000.00
# 20            12   $10,540,000.00
# 21            26  $116,600,000.00
# 22            87  $448,140,000.00
# 23            56  $291,050,000.00
# 24            28  $330,360,000.00
# 25            26  $325,100,000.00
# 26            93  $412,560,000.00
# 27            40  $229,020,000.00
# 28            65  $335,060,000.00
# 29            90  $140,370,000.00
# 30            68  $335,450,000.00
# 31            79   $84,160,000.00
# 32            59   $46,370,000.00

# %%
marvel_df.to_json(orient='records')
# Out:
# '[{"title":"Captain America","entity":"MARVEL","year":1944,"mpa_rating":"Approved","imdb_rating":5.5,"tomato_meter":0,"imdb_gross":"$0.00"},{"title":"Howard the Duck","entity":"MARVEL","year":1986,"mpa_rating":"PG","imdb_rating":4.7,"tomato_meter":13,"imdb_gross":"$16,300,000.00"},{"title":"Blade","entity":"MARVEL","year":1998,"mpa_rating":"R","imdb_rating":7.1,"tomato_meter":55,"imdb_gross":"$70,090,000.00"},{"title":"X-Men","entity":"MARVEL","year":2000,"mpa_rating":"PG-13","imdb_rating":7.4,"tomato_meter":82,"imdb_gross":"$157,300,000.00"},{"title":"Blade II","entity":"MARVEL","year":2002,"mpa_rating":"R","imdb_rating":6.7,"tomato_meter":57,"imdb_gross":"$82,350,000.00"},{"title":"Spider-Man","entity":"MARVEL","year":2002,"mpa_rating":"PG-13","imdb_rating":7.3,"tomato_meter":90,"imdb_gross":"$403,710,000.00"},{"title":"Daredevil","entity":"MARVEL","year":2003,"mpa_rating":"PG-13","imdb_rating":5.3,"tomato_meter":44,"imdb_gross":"$102,540,000.00"},{"title":"X2: X-Men United","entity":"MARVEL","year":2003,"mpa_rating":"PG-13","imdb_rating":7.4,"tomato_meter":85,"imdb_gross":"$214,950,000.00"},{"title":"Hulk","entity":"MARVEL","year":2003,"mpa_rating":"PG-13","imdb_rating":5.6,"tomato_meter":62,"imdb_gross":"$132,180,000.00"},{"title":"The Punisher","entity":"MARVEL","year":2004,"mpa_rating":"R","imdb_rating":6.4,"tomato_meter":28,"imdb_gross":"$33,680,000.00"},{"title":"Spider-Man 2","entity":"MARVEL","year":2004,"mpa_rating":"PG-13","imdb_rating":7.3,"tomato_meter":93,"imdb_gross":"$373,590,000.00"},{"title":"Blade: Trinity","entity":"MARVEL","year":2004,"mpa_rating":"R","imdb_rating":5.8,"tomato_meter":25,"imdb_gross":"$52,410,000.00"},{"title":"Elektra","entity":"MARVEL","year":2005,"mpa_rating":"PG-13","imdb_rating":4.7,"tomato_meter":11,"imdb_gross":"$24,410,000.00"},{"title":"Fantastic Four","entity":"MARVEL","year":2005,"mpa_rating":"PG-13","imdb_rating":5.7,"tomato_meter":27,"imdb_gross":"$154,700,000.00"},{"title":"X-Men: The Last Stand","entity":"MARVEL","year":2006,"mpa_rating":"PG-13","imdb_rating":6.7,"tomato_meter":57,"imdb_gross":"$234,360,000.00"},{"title":"Gh