# %%
from selenium import webdriver
import pandas as pd
import requests
from bs4 import BeautifulSoup
import csv

# %%
driver = webdriver.Chrome() 

# Define the base URL of the website
base_url = "https://www.usda.gov/media/agency-reports"

# Create a list to store all link data
all_link_data = []
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 driver = webdriver.Chrome()
#       3 # Define the base URL of the website
#       4 base_url = "https://www.usda.gov/media/agency-reports"
#
# File ~\anaconda3\envs\dev\lib\site-packages\selenium\webdriver\chrome\webdriver.py:70, in WebDriver.__init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      67 if not service:
#      68     service = Service(executable_path, port, service_args, service_log_path)
# ---> 70 super(WebDriver, self).__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      71                                 port, options,
#      72                                 service_args, desired_capabilities,
#      73                                 service_log_path, service, keep_alive)
#
# File ~\anaconda3\envs\dev\lib\site-packages\selenium\webdriver\chromium\webdriver.py:92, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      89 self.service.start()
#      91 try:
# ---> 92     RemoteWebDriver.__init__(
#      93         self,
#      94         command_executor=ChromiumRemoteConnection(
#      95             remote_server_addr=self.service.service_url,
#      96             browser_name=browser_name, vendor_prefix=vendor_prefix,
#      97             keep_alive=keep_alive, ignore_proxy=_ignore_proxy),
#      98         options=options)
#      99 except Exception:
#     100     self.quit()
#
# File ~\anaconda3\envs\dev\lib\site-packages\selenium\webdriver\remote\webdriver.py:275, in WebDriver.__init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     273 self._authenticator_id = None
#     274 self.start_client()
# --> 275 self.start_session(capabilities, browser_profile)
#
# File ~\anaconda3\envs\dev\lib\site-packages\selenium\webdriver\remote\webdriver.py:365, in WebDriver.start_session(self, capabilities, browser_profile)
#     363 w3c_caps = _make_w3c_caps(capabilities)
#     364 parameters = {"capabilities": w3c_caps}
# --> 365 response = self.execute(Command.NEW_SESSION, parameters)
#     366 if 'sessionId' not in response:
#     367     response = response['value']
#
# File ~\anaconda3\envs\dev\lib\site-packages\selenium\webdriver\remote\webdriver.py:430, in WebDriver.execute(self, driver_command, params)
#     428 response = self.command_executor.execute(driver_command, params)
#     429 if response:
# --> 430     self.error_handler.check_response(response)
#     431     response['value'] = self._unwrap_value(
#     432         response.get('value', None))
#     433     return response
#
# File ~\anaconda3\envs\dev\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created: This version of ChromeDriver only supports Chrome version 114
# Current browser version is 116.0.5845.188 with binary path C:\Program Files (x86)\Google\Chrome\Application\chrome.exe
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0097A813+48355]
# 	(No symbol) [0x0090C4B1]
# 	(No symbol) [0x00815358]
# 	(No symbol) [0x008361AC]
# 	(No symbol) [0x00831EF3]
# 	(No symbol) [0x00830579]
# 	(No symbol) [0x00860C55]
# 	(No symbol) [0x0086093C]
# 	(No symbol) [0x0085A536]
# 	(No symbol) [0x008382DC]
# 	(No symbol) [0x008393DD]
# 	GetHandleVerifier [0x00BDAABD+2539405]
# 	GetHandleVerifier [0x00C1A78F+2800735]
# 	GetHandleVerifier [0x00C1456C+2775612]
# 	GetHandleVerifier [0x00A051E0+616112]
# 	(No symbol) [0x00915F8C]
# 	(No symbol) [0x00912328]
# 	(No symbol) [0x0091240B]
# 	(No symbol) [0x00904FF7]
# 	BaseThreadInitThunk [0x76027BA9+25]
# 	RtlInitializeExceptionChain [0x76F0B79B+107]
# 	RtlClearBits [0x76F0B71F+191]

# %%
# Iterate through the next 5 pages
for page_number in range(1, 6):  # Pages 1 to 5
    # Define the URL for the current page
    url = f"{base_url}?start_date=08/01/2023&end_date=09/12/2023&page={page_number}"

    # Visit the URL using Selenium
    driver.get(url)

    # Get the page source after it's fully loaded (Selenium waits for the page to load)
    page_source = driver.page_source

    # Parse the HTML content of the page
    soup = BeautifulSoup(page_source, 'html.parser')

    # Find all elements with the specific class (modify class_name as needed)
    blocks = soup.find_all('span', class_='agency-report-title')

    # Iterate through the blocks on the current page
    for block in blocks:
        # Find all the links within the block
        links = block.find_all('a')

        # Iterate through the links within the block
        for link in links:
            # Get the URL of the link
            link_url = link.get('href')

            # Check if the link is valid (not None and not empty)
            if link_url:
                # Handle relative URLs manually by combining with the base URL
                if not link_url.startswith("http"):
                    link_url = base_url + link_url

                # Send an HTTP GET request to the full link URL
                link_response = requests.get(link_url)

                # Check if the request to the link was successful (status code 200)
                if link_response.status_code == 200:
                    # Parse the HTML content of the link's page
                    link_soup = BeautifulSoup(link_response.text, 'html.parser')

                    # Extract the title of the article
                    article_title = link_soup.title.string

                    # Extract the source information
                    source_element = link_soup.find('span', class_='attribute contact_organization')
                    source = source_element.get_text(strip=True) if source_element else ""

                    # Append the link URL, article title, and source to the all_link_data list
                    all_link_data.append([link_url, article_title, source])

    print(f"Scraped data from page {page_number}")

# Define the CSV file name
csv_file = "links_data.csv"

# Write all the link data to a CSV file
with open(csv_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Link", "Article Title", "Source"])  # Write header row
    writer.writerows(all_link_data)  # Write all link data

print(f"Data has been exported to {csv_file}")

# Close the web driver
driver.quit()
# Out:
# Scraped data from page 1
# Scraped data from page 2
# Scraped data from page 3
# Scraped data from page 4
# Scraped data from page 5
# Data has been exported to links_data.csv

# %%
df = pd.DataFrame(all_link_data)
df = df.rename(columns={0: "URL", 1: "Title and ID", 2: "Source"})
df.head()
# Out:
#                                                  URL  \
# 0  https://www.nass.usda.gov/Publications/Calenda...
# 1  https://www.nass.usda.gov/Publications/Calenda...
# 2  https://www.nass.usda.gov/Publications/Calenda...
# 3  https://www.nass.usda.gov/Publications/Calenda...
# 4  https://www.nass.usda.gov/Publications/Calenda...
#
#                                         Title and ID  \
# 0  Publication | Cotton System Consumption and St...
# 1  Publication | Fats and Oils: Oilseed Crushings...
# 2  Publication | Flour Milling Products | ID: cr5...
# 3  Publication | Grain Crushings and Co-Products ...
# 4  Publication | Honey Bee Colonies | ID: rn30113...
#
#                                      Source
# 0  National Agricultural Statistics Service
# 1  National Agricultural Statistics Service
# 2  National Agricultural Statistics Service
# 3  National Agricultural Statistics Service
# 4  National Agricultural Statistics Service
